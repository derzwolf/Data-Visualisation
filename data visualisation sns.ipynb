# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
sns.set()

# %%
netflix = pd.read_csv('netflix_titles.csv')
dd={'title':'Title',
   'release_year':'Year'}
netflix.rename(dd, axis=1, inplace=True)
netflix.head()
# Out:
#   show_id     type                  Title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Year rating   duration  \
# 0  September 25, 2021  2020  PG-13     90 min
# 1  September 24, 2021  2021  TV-MA  2 Seasons
# 2  September 24, 2021  2021  TV-MA   1 Season
# ...

# %%
dd={'title':'Title',
   'release_year':'Year'}
netflix.rename(dd, axis=1, inplace=True)

# %%
imdp = pd.read_csv('IMDB-Movie-Data.csv')
imdp.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
sns.countplot(x='type', data=netflix)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df = netflix.merge(imdp,how='inner',left_on=['Title','Year'],right_on=['Title','Year'])
df.head()
# Out:
#   show_id   type            Title                   director  \
# 0     s28  Movie        Grown Ups               Dennis Dugan
# 1    s134  Movie          Chappie             Neill Blomkamp
# 2    s143  Movie  Freedom Writers        Richard LaGravenese
# 3    s144  Movie    Green Lantern            Martin Campbell
# 4    s179  Movie    The Interview  Evan Goldberg, Seth Rogen
#
#                                                 cast  \
# 0  Adam Sandler, Kevin James, Chris Rock, David S...
# 1  Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# 2  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 3  Ryan Reynolds, Blake Lively, Peter Sarsgaard, ...
# 4  James Franco, Seth Rogen, Lizzy Caplan, Randal...
#
#                        country          date_added  Year rating duration  ...  \
# 0                United States  September 20, 2021  2010  PG-13  103 min  ...
# 1  South Africa, United States   September 1, 2021  2015      R  121 min  ...
# ...

# %%
df.sample(101)
df.set_index('show_id')
df.isna().sum()
# Out:
# show_id                0
# type                   0
# Title                  0
# director               0
# cast                   0
# country                1
# date_added             0
# Year                   0
# rating                 0
# duration               0
# listed_in              0
# description            0
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)    36
# Metascore             14
# dtype: int64

# %%
def check(x):
    if 'Dramas' in (x):
        return True
    else:
        return False

# %%
df['is_drama'] = df['listed_in'].apply(lambda x: check(x))

# %%
Movies = df[df['type'] == 'Movie']
#Series = df[df['type'] == 'TV Show']
#Series
# Out:
# Empty DataFrame
# Columns: [show_id, type, Title, director, cast, country, date_added, Year, rating, duration, listed_in, description, Rank, Genre, Description, Director, Actors, Runtime (Minutes), Rating, Votes, Revenue (Millions), Metascore, is_drama]
# Index: []
#
# [0 rows x 23 columns]

# %%
Movies['duration_int']= Movies['duration'].str.replace(' min', '')
Movies['duration_int']= Movies['duration_int'].astype('float')
Movies.info()
Movies
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 238
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   show_id             239 non-null    object
#  1   type                239 non-null    object
#  2   Title               239 non-null    object
#  3   director            239 non-null    object
#  4   cast                239 non-null    object
#  5   country             238 non-null    object
#  6   date_added          239 non-null    object
#  7   Year                239 non-null    int64
#  8   rating              239 non-null    object
#  9   duration            239 non-null    object
#  10  listed_in           239 non-null    object
#  11  description         239 non-null    object
#  12  Rank                239 non-null    int64
#  13  Genre               239 non-null    object
#  14  Description         239 non-null    object
# ...

# %%
#Movies['is_drama'] = Movies['is_drama'].astype(object)#sns.boxplot(x = Movies['duration_int'],y =Movies['Genre'])
#important_ to select first
idf = Movies.loc[Movies['duration_int']][Movies['is_drama'] == True]
idf.head()
# Out:
# /var/folders/_g/ks06ypzd0b77vz99vm0j17940000gn/T/ipykernel_27512/2842329533.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   idf = Movies.loc[Movies['duration_int']][Movies['is_drama'] == True]
#     show_id   type            Title               director  \
# 114   s6333  Movie   Bleed for This            Ben Younger
# 112   s6206  Movie            Babel  Alejandro G. Iñárritu
# 114   s6333  Movie   Bleed for This            Ben Younger
# 148   s7048  Movie  I, Daniel Blake              Ken Loach
# 112   s6206  Movie            Babel  Alejandro G. Iñárritu
#
#                                                   cast  \
# 114  Miles Teller, Aaron Eckhart, Katey Sagal, Ciar...
# 112  Brad Pitt, Cate Blanchett, Gael García Bernal,...
# 114  Miles Teller, Aaron Eckhart, Katey Sagal, Ciar...
# 148  Dave Johns, Hayley Squires, Briana Shann, Dyla...
# 112  Brad Pitt, Cate Blanchett, Gael García Bernal,...
#
# ...

# %%
plt.boxplot(idf.duration_int)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff4a293a550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff4a293aaf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff4a293a2e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff4a29450d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff4a29453a0>],
#  'means': []}

# %%
sns.boxplot(idf.is_drama, idf.duration_int)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='is_drama', ylabel='duration_int'>

# %%
duration  = Movies[(Movies['duration_int']>=60) & (Movies['duration_int']<=200)]
sns.displot(duration.duration_int,kde=True)

# %%
sns.relplot(duration.Rating, duration.duration_int, kind='line')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot(x='Rating', y='duration_int',data=duration, lowess=True)

# %%
#Movies.boxplot(column='duration_int',by='is_drama')
#drc.reset_index(inplace=True)
#new={'index':'director_name','Director':'no_of_presents'}
#drc = drc.rename(new, axis = 1)

# %%
#drc = df.loc[(df.Director.value_counts().head(10))&(df.Director)]
#drc

# %%
df['directors'] = df.director.str.split(' ', expand=True).stack().reset_index(drop=True)
df
# Out:
#     show_id   type                          Title                   director  \
# 0       s28  Movie                      Grown Ups               Dennis Dugan
# 1      s134  Movie                        Chappie             Neill Blomkamp
# 2      s143  Movie                Freedom Writers        Richard LaGravenese
# 3      s144  Movie                  Green Lantern            Martin Campbell
# 4      s179  Movie                  The Interview  Evan Goldberg, Seth Rogen
# ..      ...    ...                            ...                        ...
# 234   s8751  Movie                  Winter's Bone               Debra Granik
# 235   s8783  Movie                    Yoga Hosers                Kevin Smith
# 236   s8791  Movie  You Don't Mess with the Zohan               Dennis Dugan
# 237   s8803  Movie                         Zodiac              David Fincher
# 238   s8805  Movie                     Zombieland            Ruben Fleischer
#
# ...

# %%
drrrr = df.directors.value_counts().head(10)
drrrr
# Out:
# John        6
# James       4
# David       4
# Martin      3
# Mike        3
# Wan         3
# Tom         3
# Hooper      2
# del         2
# Hillcoat    2
# Name: directors, dtype: int64

# %%
#drc1 = df.groupby('Director').count()
#drc1

# %%
#drc = df.Director.value_counts()
#drc

# %%
sns.countplot(drrrr)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='directors', ylabel='count'>

# %%
df['year'] = pd.to_datetime(df['date_added']).dt.year

# %%
sns.displot(df['Rating'], kde=True)

# %%
#df.type df.year 
df.info()
df.dropna(how='any' ,subset=['country'], inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 238
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   show_id             239 non-null    object
#  1   type                239 non-null    object
#  2   Title               239 non-null    object
#  3   director            239 non-null    object
#  4   cast                239 non-null    object
#  5   country             238 non-null    object
#  6   date_added          239 non-null    object
#  7   Year                239 non-null    int64
#  8   rating              239 non-null    object
#  9   duration            239 non-null    object
#  10  listed_in           239 non-null    object
#  11  description         239 non-null    object
#  12  Rank                239 non-null    int64
#  13  Genre               239 non-null    object
#  14  Description         239 non-null    object
# ...

# %%
#df['added_count'] = df.loc[df['Title'][df.groupby('year').count()]]
#df.added_count = abc.Title

# %%
abc = df.groupby(['year','type']).count()
abc.reset_index(inplace=True)

# %%
abc['added_Title'] = abc['Title']

# %%
abc
# Out:
#    year   type  show_id  Title  director  cast  country  date_added  Year  \
# 0  2015  Movie        1      1         1     1        1           1     1
# 1  2016  Movie        9      9         9     9        9           9     9
# 2  2017  Movie       24     24        24    24       24          24    24
# 3  2018  Movie       29     29        29    29       29          29    29
# 4  2019  Movie       55     55        55    55       55          55    55
# 5  2020  Movie       57     57        57    57       57          57    57
# 6  2021  Movie       63     63        63    63       63          63    63
#
#    rating  ...  Director  Actors  Runtime (Minutes)  Rating  Votes  \
# 0       1  ...         1       1                  1       1      1
# 1       9  ...         9       9                  9       9      9
# 2      24  ...        24      24                 24      24     24
# 3      29  ...        29      29                 29      29     29
# ...

# %%
df.country.isna().sum()
# Out:
# 0

# %%
sns.lmplot(y='added_Title', x='year', hue= 'type', data=abc)

# %%
#sns.lmplot(y='added_count', x='year', hue='type', data=df)
#sns.lmplot(x='Title', y='year', hue='type', data=abc)

# %%
sns.displot(df.Rating,kde=True)

# %%
#mpf = df[(df['country'] == 'France')]
#mpf.['series'] =

# %%
def checkfr(x):
    if 'France' in (x):
        return True
    else:
        return False

# %%
df['is_FR'] = df['country'].apply(lambda x: checkfr(x))

# %%
z = df[['Title','Votes','type']][df['is_FR'] == True]
hi=z.groupby('Votes').max().sort_values(by='Votes', ascending=False)
hi.reset_index(inplace=True)
hii = hi.head(5)
hii
# Out:
#     Votes              Title   type
# 0  557965   The Intouchables  Movie
# 1  338280  The Da Vinci Code  Movie
# 2  259182               Hugo  Movie
# 3  253417              Babel  Movie
# 4  218679            Unknown  Movie

# %%
#hi['just_movies'] = hi['type']== 'Movie'
#hi['just_series'] = hi['type']== 'Tv show'

#movies_list = hi[hi.just_movies== True].head(5)
#movies_list

# %%
#series_list = hi[hi.just_series== True].head(5)
#series_list

# %%
g = sns.FacetGrid(hii, row = 'type')
g.map(plt.plot,'Votes','Title', alpha=.5, color='green')

# %%
a = sns.PairGrid(hii.iloc[:,:], hue = 'type')
a.map(plt.scatter,alpha=.5)

# %%
sns.catplot(x='Votes', y='Title',kind='bar',hue='type', data=movies_list)

# %%
sns.lmplot(x='Metascore',y='Year',hue='type',data=df)

# %%
sns.relplot(x='Rating',y='Year',hue='type',data=df)

# %%
#Rank,Metascore,Rating all of them show same regression line trend

# %%
def checkfr(x):
    if 'United States' in (x):
        return True
    else:
        return False

df['is_US'] = df['country'].apply(lambda x: checkfr(x))

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 0 to 238
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   show_id             238 non-null    object
#  1   type                238 non-null    object
#  2   Title               238 non-null    object
#  3   director            238 non-null    object
#  4   cast                238 non-null    object
#  5   country             238 non-null    object
#  6   date_added          238 non-null    object
#  7   Year                238 non-null    int64
#  8   rating              238 non-null    object
#  9   duration            238 non-null    object
#  10  listed_in           238 non-null    object
#  11  description         238 non-null    object
#  12  Rank                238 non-null    int64
#  13  Genre               238 non-null    object
#  14  Description         238 non-null    object
# ...

# %%
usact = df[(df['Rating'] >= 7)&(df['is_US']== True)]
usact.Actors.head()
# Out:
# 2    Hilary Swank, Imelda Staunton, Patrick Dempsey...
# 6    Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 7    Seth Rogen, James Franco, Gary Cole, Danny McB...
# 8    Hailee Steinfeld, Haley Lu Richardson, Blake J...
# 9    Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...
# Name: Actors, dtype: object

# %%
#usact = df[df['is_US']== True]

# %%
usact.loc[:,['Rating','is_US','Actors','year']]
# Out:
#      Rating  is_US                                             Actors  year
# 2       7.5   True  Hilary Swank, Imelda Staunton, Patrick Dempsey...  2021
# 6       8.8   True  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2021
# 7       7.0   True  Seth Rogen, James Franco, Gary Cole, Danny McB...  2021
# 8       7.4   True  Hailee Steinfeld, Haley Lu Richardson, Blake J...  2021
# 9       8.4   True  Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...  2021
# ..      ...    ...                                                ...   ...
# 228     7.4   True  George Clooney, Vera Farmiga, Anna Kendrick,Ja...  2020
# 231     7.5   True  Bryan Cranston, Jennifer Garner, Beverly D'Ang...  2019
# 234     7.2   True  Jennifer Lawrence, John Hawkes, Garret Dillahu...  2019
# 237     7.7   True  Jake Gyllenhaal, Robert Downey Jr., Mark Ruffa...  2019
# 238     7.7   True  Jesse Eisenberg, Emma Stone, Woody Harrelson,A...  2019
#
# [95 rows x 4 columns]

# %%
usact.Actors
# Out:
# 2      Hilary Swank, Imelda Staunton, Patrick Dempsey...
# 6      Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 7      Seth Rogen, James Franco, Gary Cole, Danny McB...
# 8      Hailee Steinfeld, Haley Lu Richardson, Blake J...
# 9      Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...
#                              ...
# 228    George Clooney, Vera Farmiga, Anna Kendrick,Ja...
# 231    Bryan Cranston, Jennifer Garner, Beverly D'Ang...
# 234    Jennifer Lawrence, John Hawkes, Garret Dillahu...
# 237    Jake Gyllenhaal, Robert Downey Jr., Mark Ruffa...
# 238    Jesse Eisenberg, Emma Stone, Woody Harrelson,A...
# Name: Actors, Length: 95, dtype: object

# %%
#usact.Actors.apply(lambda x: str(x).split(','))

# %%
#usact['Actors'] = usact.Actors.str.split(',', expand=True)

# %%
xy = usact.loc[:,['Title','Rating','is_US','Actors','year']]

# %%
xy
# Out:
#                      Title  Rating  is_US  \
# 2          Freedom Writers     7.5   True
# 6                Inception     8.8   True
# 7        Pineapple Express     7.0   True
# 8    The Edge of Seventeen     7.4   True
# 9         Django Unchained     8.4   True
# ..                     ...     ...    ...
# 228          Up in the Air     7.4   True
# 231              Wakefield     7.5   True
# 234          Winter's Bone     7.2   True
# 237                 Zodiac     7.7   True
# 238             Zombieland     7.7   True
#
#                                                 Actors  year
# 2    Hilary Swank, Imelda Staunton, Patrick Dempsey...  2021
# 6    Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2021
# 7    Seth Rogen, James Franco, Gary Cole, Danny McB...  2021
# 8    Hailee Steinfeld, Haley Lu Richardson, Blake J...  2021
# 9    Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...  2021
# ..                                                 ...   ...
# ...

# %%
#xy['Actors_'] = xy.Actors.str.split(',', expand=True).stack().reset_index(drop=True)

# %%
#slpit_xy = xy['Actors'].str.split(',', expand=True)

# %%
#slpit_xy

# %%
xy[['1st_actor','2nd_actor','3rd_actor','4th_actor']] = xy['Actors'].str.split(',', expand=True)

# %%
xy
# Out:
#                      Title  Rating  is_US  \
# 2          Freedom Writers     7.5   True
# 6                Inception     8.8   True
# 7        Pineapple Express     7.0   True
# 8    The Edge of Seventeen     7.4   True
# 9         Django Unchained     8.4   True
# ..                     ...     ...    ...
# 228          Up in the Air     7.4   True
# 231              Wakefield     7.5   True
# 234          Winter's Bone     7.2   True
# 237                 Zodiac     7.7   True
# 238             Zombieland     7.7   True
#
#                                                 Actors  year  \
# 2    Hilary Swank, Imelda Staunton, Patrick Dempsey...  2021
# 6    Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2021
# 7    Seth Rogen, James Franco, Gary Cole, Danny McB...  2021
# 8    Hailee Steinfeld, Haley Lu Richardson, Blake J...  2021
# 9    Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...  2021
# ..                                                 ...   ...
# ...

# %%
a2 = xy.groupby(['1st_actor','2nd_actor','3rd_actor','4th_actor'])['Title'].count()
a2.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1st_actor        2nd_actor         3rd_actor             4th_actor
# Alia Shawkat      Nancy Kwan        Annabelle Attanasio  Alfred Molina            1
# Amy Adams         Jake Gyllenhaal   Michael Shannon       Aaron Taylor-Johnson    1
# Anika Noni Rose   Keith David       Oprah Winfrey         Bruno Campos            1
# Annette Bening    Elle Fanning      Greta Gerwig          Billy Crudup            1
# Anthony Hopkins   Ryan Gosling      David Strathairn     Rosamund Pike            1
#                                                                                  ..
# Tom Hardy         Shia LaBeouf      Guy Pearce            Jason Clarke            1
# Vera Farmiga      Patrick Wilson    Madison Wolfe         Frances O'Connor        1
# Viggo Mortensen   George MacKay     Samantha Isler       Annalise Basso           1
# Will Smith        Rosario Dawson    Woody Harrelson      Michael Ealy             1
# ...

# %%
a1 = xy.groupby('Rating')['Title'].count()
a1
# Out:
# Rating
# 7.0     7
# 7.1    11
# 7.2     6
# 7.3     7
# 7.4     8
# 7.5    11
# 7.6     4
# 7.7    11
# 7.8     4
# 7.9     4
# 8.0     8
# 8.1     7
# 8.2     2
# 8.3     2
# 8.4     1
# 8.5     1
# 8.8     1
# Name: Title, dtype: int64

# %%
df.rename()

# %%
xy['4th_actor'].isna().sum()
# Out:
# 0

# %%
lol=xy.loc[:,['Title','Rating','is_US','1st_actor','2nd_actor','3rd_actor','4th_actor','year']]

# %%
lol
# Out:
#                      Title  Rating  is_US          1st_actor  \
# 2          Freedom Writers     7.5   True       Hilary Swank
# 6                Inception     8.8   True  Leonardo DiCaprio
# 7        Pineapple Express     7.0   True         Seth Rogen
# 8    The Edge of Seventeen     7.4   True   Hailee Steinfeld
# 9         Django Unchained     8.4   True         Jamie Foxx
# ..                     ...     ...    ...                ...
# 228          Up in the Air     7.4   True     George Clooney
# 231              Wakefield     7.5   True     Bryan Cranston
# 234          Winter's Bone     7.2   True  Jennifer Lawrence
# 237                 Zodiac     7.7   True    Jake Gyllenhaal
# 238             Zombieland     7.7   True    Jesse Eisenberg
#
#                  2nd_actor           3rd_actor         4th_actor  year
# 2          Imelda Staunton     Patrick Dempsey       Scott Glenn  2021
# 6     Joseph Gordon-Levitt          Ellen Page      Ken Watanabe  2021
# ...

# %%
#lol5 = lol['1st_actor'],lol['2nd_actor'].combine_first(lol['3rd_actor'],lol['4th_actor'])
#lol5

# %%
lol3 = pd.concat([lol['1st_actor'],lol['2nd_actor'],lol['3rd_actor'],lol['4th_actor']])
lol3.duplicated().sum()
# Out:
# 47

# %%
lol4=lol3.value_counts().head(10)
lol4
# Out:
# Leonardo DiCaprio       4
# Tom Hardy               3
# Joseph Gordon-Levitt    3
#  Anna Kendrick          3
# Jake Gyllenhaal         3
# Rooney Mara             2
#  Kyle Chandler          2
# Brad Pitt               2
# Cate Blanchett          2
# Ryan Gosling            2
# dtype: int64

# %%
#lol.groupby(['1st_actor','2nd_actor','3rd_actor','4th_actor']).count().reset_index()

# %%
lol['1st_actor'].nunique()
# Out:
# 75
